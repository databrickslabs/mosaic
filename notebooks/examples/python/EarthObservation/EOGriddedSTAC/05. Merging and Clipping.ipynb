# %% [markdown]
# # Merging and Clipping
#
# > Making use of H3 global grid indexing when working with rasters. For this example series, we focus on B04 (red), B03 (green), B02 (blue), and B08 (nir).
#
# ---
# __Last Update:__ 18 JAN 2024 [Mosaic 0.3.14]

# %% [markdown]
# ## Setup Notes
#
# > Raster processing is memory intensize. Here are some config tips.
#
# * This notebook was run on AWS [r5d.4xlarge](https://www.databricks.com/product/pricing/product-pricing/instance-types) instances (1-10 workers auto-scaling for up to 160 concurrent tasks).
# * __Optional:__ Prior to launching, the following can be added to the cluster spark configs, adapted from this databricks [blog](https://www.databricks.com/blog/2015/05/28/tuning-java-garbage-collection-for-spark-applications.html) and these JVM tuning [docs](https://docs.oracle.com/cd/E40972_01/doc.70/e40973/cnf_jvmgc.htm#autoId2): `spark.executor.extraJavaOptions -XX:+UseG1GC -XX:+PrintFlagsFinal -XX:InitiatingHeapOccupancyPercent=35 -XX:G1HeapRegionSize=32M -XX:ParallelGCThreads=16 -XX:ConcGCThreads=4`. _This optimization is not required for this example._

# %% [markdown]
# ## Imports + Config

# %%
# %pip install --quiet 'databricks-mosaic<0.4,>=0.3'

# %%
# %pip install --quiet rasterio==1.4.3 gdal==3.10.3 pystac pystac_client planetary_computer tenacity rich pandas==1.5.3
# Out:
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# -- configure AQE for more compute heavy operations
spark.conf.set("spark.sql.adaptive.coalescePartitions.enabled", False)
spark.conf.set("spark.sql.shuffle.partitions", 512)

spark.conf.set("spark.databricks.labs.mosaic.jar.autoattach", "false")
spark.conf.set("spark.databricks.labs.mosaic.geometry.api", "JTS")
spark.conf.set("spark.databricks.labs.mosaic.index.system", "H3")
spark.conf.set("spark.databricks.labs.mosaic.raster.api", "GDAL")

# -- import databricks + delta + spark functions
from delta.tables import *
from pyspark.databricks.sql import functions as dbf
from pyspark.sql import functions as F
from pyspark.sql.functions import col, udf
from pyspark.sql.types import *

# -- setup mosaic
import mosaic as mos

mos.enable_mosaic(spark, dbutils)
mos.enable_gdal(spark)

# -- other imports
from datetime import datetime
from io import BytesIO
from matplotlib import pyplot
from rasterio.io import MemoryFile

import library
import os
import pathlib
import planetary_computer
import pystac_client
import rasterio
import requests
import warnings

warnings.simplefilter("ignore")
# Out:
# GDAL enabled.
#
# GDAL 3.10.3, released 2025/04/01

# %%
mos.__version__
# Out:
# '0.4.3'

# %%
# %reload_ext autoreload
# %autoreload 2
# %reload_ext library

# %% [markdown]
# ### Databricks Catalog + Schema
#
# > This is for reading and writing out table(s). __Note: these should already exists after running notebook 01.__

# %%
# adjust to match your catalog + schema
catalog_name = "milos_dev"
db_name = "mosaic_dev_eo_alaska"

sql(f"""USE CATALOG {catalog_name}""")
sql(f"""USE DATABASE {db_name}""")
# Out:
# DataFrame[]

# %% [markdown]
# ## Data load

# %% [markdown]
# We can easily browse the data we have downloaded previously (notebook 01). The download metadata is stored as a delta table.

# %%
# %sql show tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>mosaic_dev_eo_alaska</td><td>band_b02</td><td>false</td></tr><tr><td>mosaic_dev_eo_alaska</td><td>band_b02_h3</td><td>false</td></tr><tr><td>mosaic_dev_eo_alaska</td><td>band_b02_tile</td><td>false</td></tr><tr><td>mosaic_dev_eo_alaska</td><td>band_b03</td><td>false</td></tr><tr><td>mosaic_dev_eo_alaska</td><td>band_b03_h3</td><td>false</td></tr><tr><td>mosaic_dev_eo_alaska</td><td>band_b03_tile</td><td>false</td></tr><tr><td>mosaic_dev_eo_alaska</td><td>band_b04</td><td>false</td></tr><tr><td>mosaic_dev_eo_alaska</td><td>band_b04_h3</td><td>false</td></tr><tr><td>mosaic_dev_eo_alaska</td><td>band_b04_tile</td><td>false</td></tr><tr><td>mosaic_dev_eo_alaska</td><td>band_b08</td><td>false</td></tr><tr><td>mosaic_dev_eo_alaska</td><td>band_b08_h3</td><td>false</td></tr><tr><td>mosaic_dev_eo_alaska</td><td>band_b08_tile</td><td>false</td></tr><tr><td>mosaic_dev_eo_alaska</td><td>band_stack</td><td>false</td></tr><tr><td>mosaic_dev_eo_alaska</td><td>ndvi_calc</td><td>false</td></tr></tbody></table></div>

# %%
tile_df = spark.table("band_b02_tile")
h3_df =spark.table("band_b02_h3")

# %% [markdown]
# ## Merge
# We can easily merge tiles using `rst_merge_agg`, from [docs](https://databrickslabs.github.io/mosaic/api/raster-functions.html?highlight=rst_mergeagg#rst_mergeagg):
#
# > Combines a collection of rasters into a single raster. The rasters do not need to have the same extent. The rasters must have the same coordinate reference system. The rasters are combined using gdalwarp. The noData value needs to be initialised; if not, the non valid pixels may introduce artifacts in the output raster. The rasters are stacked in the order they are provided. This order is randomized since this is an aggregation function. If the order of rasters is important please first collect rasters and sort them by metadata information and then use rst_merge function. The output raster will have the extent covering all input rasters. The output raster will have the same number of bands as the input rasters. The output raster will have the same pixel type as the input rasters. The output raster will have the same pixel size as the highest resolution input rasters. The output raster will have the same coordinate reference system as the input rasters.

# %% [markdown]
# _Here we merge back an 'item_id' tiles from the same area as looked at previously._

# %%
display(
  tile_df
    .filter(col("item_id").contains("_R028_"))
    .groupBy("item_id")
      .count()
    .orderBy(F.desc("count"))
    .limit(25)
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>item_id</th><th>count</th></tr></thead><tbody><tr><td>S2A_MSIL2A_20210602T200851_R028_T08VPK_20210603T115336</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T08UNF_20210603T121544</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T09VUG_20210603T123235</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T09VUE_20210603T121321</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T08UMF_20210603T112756</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T08UNG_20210603T122031</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T08VNK_20210603T113453</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T08VNH_20210603T125228</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T08VNM_20210603T111415</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T08UMG_20210603T105432</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T08VMJ_20210603T103016</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T08VNL_20210603T113536</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T09VUD_20210603T125748</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T09VUF_20210603T125722</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T08VPH_20210603T112157</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T08VMH_20210603T130006</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T08VNJ_20210603T100411</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T08ULF_20210603T112526</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T08UNE_20210603T122404</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T08VPL_20210603T110239</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T08VPJ_20210603T125818</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T08VPM_20210603T121650</td><td>16</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T08UME_20210603T100603</td><td>4</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T09VVE_20210603T101218</td><td>4</td></tr><tr><td>S2A_MSIL2A_20210602T200851_R028_T08VMM_20210603T111656</td><td>4</td></tr></tbody></table></div>

# %%
to_plot = (
  tile_df
    .filter("item_id = 'S2A_MSIL2A_20210602T200851_R028_T08VNL_20210603T113536'")
    .groupBy("item_id")
    .agg(mos.rst_merge_agg("tile").alias("tile"))
  .collect()
)

# %%
library.plot_raster(to_plot[0]["tile"]["raster"])

# %% [markdown]
# Mosaic framework provides the same tessellation principles for both vector and raster data. We can project both vector and raster data into a unified grid and from there it is very easy to combine and join raster to raster, vector to vector and raster to vector data. _Below we look at a given H3 cellid with multiple tiles within._

# %% [markdown]
# _[1] Find index_id(s) with 2+ tiles._

# %%
display (
  h3_df
  .groupBy("index_id")
    .count()
  .orderBy(F.desc("count"))
  .limit(25)
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>index_id</th><th>count</th></tr></thead><tbody><tr><td>608200739197550591</td><td>8</td></tr><tr><td>608208756240547839</td><td>8</td></tr><tr><td>608600190164664319</td><td>8</td></tr><tr><td>608216575815712767</td><td>8</td></tr><tr><td>608208760166416383</td><td>8</td></tr><tr><td>608215576027856895</td><td>8</td></tr><tr><td>608208755787563007</td><td>8</td></tr><tr><td>608598142270570495</td><td>8</td></tr><tr><td>608203947923996671</td><td>8</td></tr><tr><td>608200755739885567</td><td>8</td></tr><tr><td>608198299622572031</td><td>8</td></tr><tr><td>608220202932371455</td><td>8</td></tr><tr><td>608208756307656703</td><td>8</td></tr><tr><td>608215578292781055</td><td>8</td></tr><tr><td>608216603095465983</td><td>8</td></tr><tr><td>608597395751567359</td><td>8</td></tr><tr><td>608220776729935871</td><td>8</td></tr><tr><td>608220202865262591</td><td>8</td></tr><tr><td>608216605360390143</td><td>8</td></tr><tr><td>608600190231773183</td><td>8</td></tr><tr><td>608215594835116031</td><td>8</td></tr><tr><td>608600175534931967</td><td>8</td></tr><tr><td>608216591032647679</td><td>8</td></tr><tr><td>608600175602040831</td><td>8</td></tr><tr><td>608216590965538815</td><td>8</td></tr></tbody></table></div>

# %% [markdown]
# _[2] Collect list of tiles for the index id(s) chosen._
#
# > Note: breaking down steps for clarity. See that 'tile' column is now a list of tiles for the 'index_id'.

# %%
for_plot = (
   h3_df
  .filter("index_id == 608200739197550591")
  .groupBy("index_id")
  .agg(
    F.count(F.lit(1)).alias("cnt"),
    F.collect_list("tile").alias("tile")
  )
  .orderBy(F.desc("cnt"))
)
display(for_plot)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>index_id</th><th>cnt</th><th>tile</th></tr></thead><tbody><tr><td>608200739197550591</td><td>8</td><td>List(List(608200739197550591, SUkqAAgAAAATAAABAwABAAAAlwEAAAEBAwABAAAAiQAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/16267007901700763992/raster_e35d67ef_34ea_456c_9c95_5472e23b8c96.tif, last_error -> , all_parents -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXQ_20210603T161812_20210602-224529.tif, driver -> GTiff, parentPath -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXQ_20210603T161812_20210602-224529.tif, last_command -> gdalwarp -wo CUTLINE_ALL_TOUCHED=TRUE -cutline /tmp/raster_tmp/raster_tmp/16267007901700763992/raster_a2025527_b004_4601_9a9e_930072948d67.shp -crop_to_cutline -of GTiff -co TILED=YES -co COMPRESS=DEFLATE)), List(608200739197550591, SUkqAAgAAAATAAABAwABAAAAdgEAAAEBAwABAAAAfgAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/506321610436241203/raster_eefeadfc_6fae_42c4_b21f_e45538de23b7.tif, last_error -> , all_parents -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T04WDV_20210603T143924_20210602-224529.tif, driver -> GTiff, parentPath -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T04WDV_20210603T143924_20210602-224529.tif, last_command -> gdalwarp -wo CUTLINE_ALL_TOUCHED=TRUE -cutline /tmp/raster_tmp/raster_tmp/506321610436241203/raster_bd0f877e_d201_44e9_b19f_ed94576fc5fe.shp -crop_to_cutline -of GTiff -co TILED=YES -co COMPRESS=DEFLATE)), List(608200739197550591, SUkqAAgAAAATAAABAwABAAAAdgEAAAEBAwABAAAAfgAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/2340042336635983021/raster_e9f297a8_4d89_4242_bc72_cc62627297ba.tif, last_error -> , all_parents -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T04WDA_20210603T144008_20210602-224529.tif, driver -> GTiff, parentPath -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T04WDA_20210603T144008_20210602-224529.tif, last_command -> gdalwarp -wo CUTLINE_ALL_TOUCHED=TRUE -cutline /tmp/raster_tmp/raster_tmp/2340042336635983021/raster_a2779c0c_339b_46cf_ae6e_3ecb6749de57.shp -crop_to_cutline -of GTiff -co TILED=YES -co COMPRESS=DEFLATE)), List(608200739197550591, SUkqAAgAAAATAAABAwABAAAAlAEAAAEBAwABAAAAhwAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/3976308782377350441/raster_fc5758fc_b5bb_40f2_b518_eb67363c8536.tif, last_error -> , all_parents -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434_20210602-224529.tif, driver -> GTiff, parentPath -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434_20210602-224529.tif, last_command -> gdalwarp -wo CUTLINE_ALL_TOUCHED=TRUE -cutline /tmp/raster_tmp/raster_tmp/3976308782377350441/raster_7b4af8fa_f29f_4dde_b540_42bb3a165f08.shp -crop_to_cutline -of GTiff -co TILED=YES -co COMPRESS=DEFLATE)), List(608200739197550591, SUkqAAgAAAATAAABAwABAAAAcwEAAAEBAwABAAAAfQAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/r ...

# %% [markdown]
# _[3] Call `rst_combineavg` on the collected 'tile' list._
#
# > Note: this replaces the initial 'tile' list column with a single raster which uses the average pixel value for any overlaps.

# %%
for_plot1 = for_plot.withColumn("tile", mos.rst_combineavg("tile"))
for_plot1.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>index_id</th><th>cnt</th><th>tile</th></tr></thead><tbody><tr><td>608200739197550591</td><td>8</td><td>List(608200739197550591, SUkqAAgAAAATAAABAwABAAAAlwEAAAEBAwABAAAAiQAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/13167466954560929713/raster_77f76ccd_ef42_498e_ab35_2a57ddbf18e8.tif, last_error -> , all_parents -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T04WDV_20210603T143924_20210602-224529.tif, driver -> GTiff, parentPath -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T04WDV_20210603T143924_20210602-224529.tif, last_command -> gdal_translate -of GTiff -co TILED=YES -co COMPRESS=DEFLATE))</td></tr></tbody></table></div>

# %% [markdown]
# _[4] Collect to render._

# %%
to_plot = for_plot1.collect()

# %%
library.plot_raster(to_plot[0]["tile"]["raster"])

# %% [markdown]
# ## Raster for Arbitrary Corridors
#
# > To illustrate how easy it is to combine vector and raster data we will use a traditionally hard problem. Extraction of raster data for an arbitrary corridors.
#
# __Notes:__
#
# 1. Though we specify a WKT for the corridor below, you can pull any any vector data including popular formats such as shapefiles, geodatabases, and geoparquet as well as supported columnar interchange formats (WKT, WKB, GeoJSON). This is covered in other material, but rest assured that you have the entire arsenal of product, DBLabs Mosaic, and external library supplied functions at your disposal.
# 1. We use the same H3 resolution of `7` to match our earlier preparation in `h3_df` as the 'index_id' will be the basis of the join.

# %%
line_example = "LINESTRING(-158.34445841325555 68.0176784075422,-155.55393106950555 68.0423396963395,-154.82883341325555 67.84431100260183,-159.33322794450555 67.81114172848677,-160.01438028825555 67.47684671455214,-154.43332560075555 67.56925103744871,-154.01584513200555 67.30791374746678,-160.16818888200555 67.25700024664256,-160.58566935075555 66.94924133006975,-153.73020060075555 67.0693906319206,-154.49924356950555 66.70715520513478,-160.12424356950555 66.70715520513478,-159.02561075700555 66.37476822845568,-154.56516153825555 66.49774379983036,-155.04855997575555 66.22462528148408,-158.76193888200555 66.16254082040112,-157.94895060075555 65.94851918639993,-155.64182169450555 66.0021934684043,-158.58615763200555 66.55900493948819,-155.26828653825555 67.43472555587037,-161.64035685075555 67.86087797718164,-161.66232950700555 67.44315575603868)"

line_df = (
  spark.createDataFrame([line_example], "string")
  .select(F.col("value").alias("wkt"))
  .select(
    mos.grid_tessellateexplode("wkt", F.lit(7)).alias("grid")
  )
  .select("grid.*")
)
print(f"count? {line_df.count():,}")
line_df.limit(1).show(vertical=True) # <- show + limiting for ipynb only
# Out:
# count? 1,391
# -RECORD 0------------------------
#  is_core  | false
#  index_id | 608199724226314239
#  wkb      | [00 80 00 00 02 0...

# %% [markdown]
# [1] We can visualise all the cells of interest for the provided arbitrary corridor. Since we are now operating in grid space it is very easy to get all raster images that match this specification.

# %%
displayHTML("""<img src="data:image/jpeg;base64,..." width="25%">""")
# Out:
# <img src="data:image/jpeg;base64,..." width="25%">

# %% [markdown]
# _Uncomment the following within databricks for actual results._

# %%
# %%mosaic_kepler
# line_df index_id h3 5_000

# %% [markdown]
# [2] We can quickly join on matching H3 'index_ids' to see which rasters match. This can be further enhanced by time filters and multiple bands (not shown here).

# %%
cells_of_interest = (
  h3_df
    .join(line_df, on=["index_id"])
)
print(f"count? {cells_of_interest.count():,}")
cells_of_interest.limit(10).display()
# Out:
# count? 545
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>index_id</th><th>item_id</th><th>date</th><th>band_name</th><th>tile</th><th>size</th><th>bbox</th><th>srid</th><th>is_core</th><th>wkb</th></tr></thead><tbody><tr><td>608200738576793599</td><td>S2B_MSIL2A_20210602T224529_R101_T04WDV_20210603T143924</td><td>2021-06-02</td><td>B02</td><td>List(608200738576793599, SUkqAAgAAAATAAABAwABAAAAewEAAAEBAwABAAAAgAAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/6015708930802371081/raster_532505af_4f97_42b5_a471_c739b6ed23ad.tif, last_error -> , all_parents -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T04WDV_20210603T143924_20210602-224529.tif, driver -> GTiff, parentPath -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T04WDV_20210603T143924_20210602-224529.tif, last_command -> gdalwarp -wo CUTLINE_ALL_TOUCHED=TRUE -cutline /tmp/raster_tmp/raster_tmp/6015708930802371081/raster_ec43d31b_ad20_4416_97ca_667296b361b7.shp -crop_to_cutline -of GTiff -co TILED=YES -co COMPRESS=DEFLATE))</td><td>9993450</td><td>AIAAAAMAAAABAAAABUEbwzAAAAAAQVycOAAAAAB/+AAAAAAAAEEbwzAAAAAAQVyBaYAAAAB/+AAAAAAAAEEdcBgAAAAAQVyBaYAAAAB/+AAAAAAAAEEdcBgAAAAAQVycOAAAAAB/+AAAAAAAAEEbwzAAAAAAQVycOAAAAAB/+AA= (truncated)</td><td>32604</td><td>false</td><td>AIAAAAIAAAACwGP3Ff/uCIFAUOe4M4Kf83/4AAAAAAAAwGP4ZdCkFc5AUOZulEw4nX/4AAAAAAAA</td></tr><tr><td>608200738576793599</td><td>S2B_MSIL2A_20210602T224529_R101_T04WDA_20210603T144008</td><td>2021-06-02</td><td>B02</td><td>List(608200738576793599, SUkqAAgAAAATAAABAwABAAAAeAEAAAEBAwABAAAAfwAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/1751487684189770501/raster_44d5c59b_7959_42ce_9e47_5edeb45a807c.tif, last_error -> , all_parents -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T04WDA_20210603T144008_20210602-224529.tif, driver -> GTiff, parentPath -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T04WDA_20210603T144008_20210602-224529.tif, last_command -> gdalwarp -wo CUTLINE_ALL_TOUCHED=TRUE -cutline /tmp/raster_tmp/raster_tmp/1751487684189770501/raster_f1bc0919_c5ff_44b8_ab26_fbfb163ba73d.shp -crop_to_cutline -of GTiff -co TILED=YES -co COMPRESS=DEFLATE))</td><td>10037183</td><td>AIAAAAMAAAABAAAABUEbwzAAAAAAQVyteYAAAAB/+AAAAAAAAEEbwzAAAAAAQVySqwAAAAB/+AAAAAAAAEEdcBgAAAAAQVySqwAAAAB/+AAAAAAAAEEdcBgAAAAAQVyteYAAAAB/+AAAAAAAAEEbwzAAAAAAQVyteYAAAAB/+AA= (truncated)</td><td>32604</td><td>false</td><td>AIAAAAIAAAACwGP3Ff/uCIFAUOe4M4Kf83/4AAAAAAAAwGP4ZdCkFc5AUOZulEw4nX/4AAAAAAAA</td></tr><tr><td>608200734399266815</td><td>S2B_MSIL2A_20210602T224529_R101_T04WDV_20210603T143924</td><td>2021-06-02</td><td>B02</td><td>List(608200734399266815, SUkqAAgAAAATAAABAwABAAAAeQEAAAEBAwABAAAAgAAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/6015708930802371081/raster_ce9767fd_d8ce_44ac_9c95_cbdb297e9911.tif, last_error -> , all_parents -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T04WDV_20210603T143924_20210602-224529.tif, driver -> GTiff, parentPath -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T04WDV_20210603T143924_20210602-224529.tif, last_command -> gdalwarp -wo CUTLINE_ALL_TOUCHED=TRUE -cutline /tmp/raster_tmp/raster_tmp/6015708930802371081/raster_1df07dac_6936_467f_94c9_9d782793e3fb.shp -crop_to_cutline -of GTiff -co TILED=YES -co COMPRESS=DEFLATE))</td><td>9993450< ...

# %% [markdown]
# [3] We can render the tile counts per H3 'index_id' to better understand areas of matching data.

# %%
plot_cells = (
  cells_of_interest
    .groupBy("index_id")
      .count()
)
print(f"count? {plot_cells.count():,}")
# Out:
# count? 307

# %%
displayHTML("""<img src="data:image/jpeg;base64,..." width="25%">""")
# Out:
# <img src="data:image/jpeg;base64,..." width="25%">

# %% [markdown]
# _Uncomment the following within databricks for actual results._

# %%
# %%mosaic_kepler
# plot_cells index_id h3 5_000

# %% [markdown]
# ### Clip to Vector
#
# What if we want rasters for all pixels in the corridor? We can apply `rst_clip`, from [docs](https://databrickslabs.github.io/mosaic/api/raster-functions.html#rst_clip):
#
# > Clips the raster to the geometry. The geometry is expected to be in the same coordinate reference system as the raster. The geometry is expected to be a polygon or a multipolygon. The output raster will have the same extent as the input geometry. The output raster will have the same number of bands as the input raster. The output raster will have the same pixel type as the input raster. The output raster will have the same pixel size as the input raster. The output raster will have the same coordinate reference system as the input raster.
#
# __Note: to get our line corridor into an accepted geometry, we will buffer it by a radius `0.001` units (degrees for 4326) which is 111m at the equator.__ This takes ~1.5 minutes using the notebook cluster.

# %% [markdown]
# _[1] We start with a buffered line geometry as basis of clipping._

# %%
poly_df = (
  spark.createDataFrame([line_example], "string")
  .select(mos.st_buffer("value", F.lit(0.001)).alias("wkt"))
)
poly_df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>wkt</th></tr></thead><tbody><tr><td>POLYGON ((-159.52452210884587 67.71837258122899, -161.63941151246843 67.85981252083407, -161.66133088758016 67.44310322753948, -161.66136032357423 67.4429094158746, -161.66142700474404 67.44272507092406, -161.66152836856963 67.44255727696095, -161.66166051969603 67.44241248221317, -161.66181837962955 67.44229625106166, -161.6619958819015 67.44221305020442, -161.6621862051991 67.4421660770037, -161.66238203550475 67.44215713661329, -161.66257584716965 67.44218657260735, -161.66276019212017 67.44225325377715, -161.66292798608328 67.44235461760275, -161.66307278083107 67.44248676872915, -161.66318901198255 67.44264462866268, -161.66327221283981 67.44282213093463, -161.66331918604052 67.44301245423222, -161.66332812643094 67.44320828453787, -161.64135547018094 67.86093050568084, -161.64132559459892 67.8611260404113, -161.641257815576 67.86131186932528, -161.64115478506005 67.86148072160982, -161.6410205342623 67.86162599068611, -161.6408603159307 67.86174199270086, -161.6406803988287 67.86182418891502, -161.64048782246144 67.86186936328819, -161.64029012164528 67.86187574831064, -159.5209276620649 67.72013665889497, -159.33366852332023 67.8120394424212, -159.3334576776463 67.8121149821454, -159.33323530806453 67.81214170137541, -154.83609497428088 67.84525755733125, -155.55406082532429 68.04133851057234, -158.34444957609944 68.01667844659063, -158.34464482860696 68.01669593651629, -158.34483291727707 68.01675118225249, -158.34500661396766 68.0168420607366, -158.3451592436123 68.0169650795594, -158.3452849407394 68.01711551117656, -158.34537887487878 68.01728757458535, -158.3454374361942 68.01747465748551, -158.3454583742071 68.01766957038608, -158.34544088428146 68.0178648228936, -158.34538563854525 68.01805291156371, -158.34529476006117 68.01822660825431, -158.34517174123835 68.01837923789896, -158.34502130962122 68.01850493502604, -158.3448492462124 68.01859886916543, -158.34466216331225 68.01865743048086, -158.34446725041167 68.01867836849378, -155.55393990666167 68.04333965729107, -155.5536676118477 68.04330436730024, -154.8285699555977 67.84527567356257, -154.82839145574889 67.845208038589, -154.8282290593668 67.84510771859713, -154.82808868363745 67.84497836891495, -154.82797544338706 67.84482470261621, -154.82789346471512 67.8446523187915, -154.82784573465267 67.84446749853608, -154.82783399232505 67.84427697608749, -154.82785866558373 67.8440876934523, -154.82791885541693 67.8439065474624, -154.82801236870662 67.84374013847729, -154.82813579813848 67.84359452988885, -154.8282846463531 67.84347502719145, -154.82845348981482 67.84338598466731, -154.82863617642755 67.84333064673089, -154.82882604969657 67.84331102971319, -159.33299230117703 67.81014343659527, -159.51693258625605 67.71986947552351, -156.71491177388248 67.5324754426273, -154.43334215527176 67.57025090041331, -154.43315109936106 67.57023569437541, -154.43296645351208 67.570184318359, -154.43279500042877 67.57009865958929, -154.01531453167877 67.30876136960737, -154.01515816334822 67.30864043451348, -154.01502863924657 67.30849110314097, -154.01493102070313 67.30831921081504, -154.01486912229447 67.30813147446071, -154.0148453627846 67.30793523012977, -154.0148606706084 67.30773814633476, -154.01491444759208 67.30754792439133, -154.01500459232724 67.30737199747907, -154.0151275822865 67.30721724017988, -154.015278611471 67.30708969984443, -154.01545177821114 67.3069943602837, -154.0156403157825 67.30693494701993, -154.01583685682465 67.30691378170668, -155.80469982050602 67.29211011018299, -156.8520291827571 67.01567745540223, -153.7302181241165 67.07039047837472, -153.7300248342744 67.0703750638096, -153.72983815300097 67.07032263601137, -153.7296650992455 67.07023516619032, -153.72951217958203 67.07011594308683, -153.72938514357156 67.06996944931932, -153.7292887675866 67.06980119284425, -153.7292266752266 67 ...

# %%
displayHTML("""<img src="data:image/jpeg;base64,..." width="25%">""")
# Out:
# <img src="data:image/jpeg;base64,..." width="25%">

# %% [markdown]
# _Uncomment the following within databricks for actual results._

# %%
# %%mosaic_kepler
# poly_df wkt geometry

# %% [markdown]
# _[2] Approximate clip (at H3 cell id level) is efficient (and should be done first)._
#
# > You might have filtered `h3_df` in some way, here we show just a single band for a single day for brevity.
#
# __Notes:__
#
# 1. Use H3 cell ids for both the rasters and the initial corridor as part of filtering to relevant data.
# 1. We write out a Delta table to help with performance.

# %%
clip_h3_df = None
clip_h3_tbl_name = "band_b02_h3_clip"
if not spark.catalog.tableExists(clip_h3_tbl_name):
  (
    poly_df
      .select(mos.grid_tessellateexplode("wkt", F.lit(7)))
      .selectExpr("index.*")
      .write
        .saveAsTable(clip_h3_tbl_name)
  )
sql(f"""OPTIMIZE {clip_h3_tbl_name} ZORDER BY (index_id)""")
clip_h3_df = spark.table(clip_h3_tbl_name)
print(f"count? {clip_h3_df.count():,}")
clip_h3_df.limit(10).display()
# Out:
# count? 1,488
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>is_core</th><th>index_id</th><th>wkb</th></tr></thead><tbody><tr><td>false</td><td>608199560396799999</td><td>AIAAAAMAAAABAAAABsBjfByvujCFQFD1mu+Kxtx/+AAAAAAAAMBjehEikPivQFD1oqV1eSR/+AAAAAAAAMBjegABKC3WQFD1giE1quJ/+AAAAAAAAMBjfAzbXl8WQFD1emZjSeN/+AAAAAAAAMBjfB2UvzhjQFD1mhBc1UJ/+AA= (truncated)</td></tr><tr><td>false</td><td>608199257752600575</td><td>AIAAAAMAAAABAAAABcBjhkEKKwlJQFDBvWWohJ1/+AAAAAAAAMBjhIM6JOy8QFDBzQYV7FZ/+AAAAAAAAMBjhHJ5juU9QFDBrNaDbBR/+AAAAAAAAMBjhmJe8jhzQFDBm3Srkzx/+AAAAAAAAMBjhkEKKwlJQFDBvWWohJ1/+AA= (truncated)</td></tr><tr><td>false</td><td>608199618026536959</td><td>AIAAAAMAAAABAAAABMBjUlnjF3rfQFDTeaMqzAZ/+AAAAAAAAMBjUWCqhDrqQFDTfcMgPUx/+AAAAAAAAMBjUXpAi0xMQFDTZWWjhVt/+AAAAAAAAMBjUlnjF3rfQFDTeaMqzAZ/+AAAAAAAAA==</td></tr><tr><td>false</td><td>608199717297324031</td><td>AIAAAAMAAAABAAAABcBjpmlUSk/hQFD0+3TpcyF/+AAAAAAAAMBjpPc5GH3zQFD1AOhNiBF/+AAAAAAAAMBjpRfbKtZTQFD036huxMZ/+AAAAAAAAMBjplbzIfgDQFD02vVfLE9/+AAAAAAAAMBjpmlUSk/hQFD0+3TpcyF/+AA= (truncated)</td></tr><tr><td>false</td><td>608199255336681471</td><td>AIAAAAMAAAABAAAABcBjgZHrHqdLQFDB523Hk9F/+AAAAAAAAMBjf5wIECywQFDB+QVhjUd/+AAAAAAAAMBjf4tnlKHGQFDB2NSu+cJ/+AAAAAAAAMBjgYFAYUN1QFDBxz1xCup/+AAAAAAAAMBjgZHrHqdLQFDB523Hk9F/+AA= (truncated)</td></tr><tr><td>false</td><td>608199393832599551</td><td>AIAAAAMAAAABAAAABsBjxWrCVjOTQFCey8EoT1h/+AAAAAAAAMBjw/fWwlN8QFCeP3aJS2p/+AAAAAAAAMBjw+YD0pXVQFCeH+HzCJJ/+AAAAAAAAMBjw+u42JXCQFCeGYgFFFh/+AAAAAAAAMBjxYEbLLS8QFCestuhYxx/+AA= (truncated)</td></tr><tr><td>false</td><td>608200756478083071</td><td>AIAAAAMAAAABAAAABsBkNR9tNESYQFDd33pF21J/+AAAAAAAAMBkNSkQQYIfQFDccRAFO1l/+AAAAAAAAMBkNTl4JeDHQFDccRgGBVd/+AAAAAAAAMBkNS/fVqvPQFDd3fzXra9/+AAAAAAAAMBkNS6e1hRqQFDd34IT9FR/+AA= (truncated)</td></tr><tr><td>false</td><td>608199532328517631</td><td>AIAAAAMAAAABAAAABMBjfTE+BJ2nQFECkjG/5Al/+AAAAAAAAMBjfLVu8T7YQFEClGH1yfV/+AAAAAAAAMBjfMBJvfTiQFECieMJgmB/+AAAAAAAAMBjfTE+BJ2nQFECkjG/5Al/+AAAAAAAAA==</td></tr><tr><td>false</td><td>608199691644960767</td><td>AIAAAAMAAAABAAAABMBj6V/43ROZQFDs/Bebunx/+AAAAAAAAMBj6h7kOxTOQFDtFaD/tKR/+AAAAAAAAMBj6WxigsTiQFDtEAiFTht/+AAAAAAAAMBj6V/43ROZQFDs/Bebunx/+AAAAAAAAA==</td></tr><tr><td>false</td><td>608199409821286399</td><td>AIAAAAMAAAABAAAABMBj6t83VuHdQFCeADyf8Gh/+AAAAAAAAMBj6xfyjqpDQFCeIpCCEmN/+AAAAAAAAMBj6vMagWKoQFCeIYVBNTh/+AAAAAAAAMBj6t83VuHdQFCeADyf8Gh/+AAAAAAAAA==</td></tr></tbody></table></div>

# %%
for_clip_df = (
   h3_df
    .join(
      clip_h3_df.selectExpr("index_id","is_core as is_core_clip", "wkb as wkb_clip").distinct(),
      ["index_id"]
    )
)
print(f"count? {for_clip_df.count():,}")
for_clip_df.limit(10).display()
# Out:
# count? 581
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>index_id</th><th>item_id</th><th>date</th><th>band_name</th><th>tile</th><th>size</th><th>bbox</th><th>srid</th><th>is_core_clip</th><th>wkb_clip</th></tr></thead><tbody><tr><td>608200678145261567</td><td>S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434</td><td>2021-06-02</td><td>B02</td><td>List(608200678145261567, SUkqAAgAAAATAAABAwABAAAAkAEAAAEBAwABAAAAgwAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/10665217145723839054/raster_46d610dd_9e9e_4607_870f_efb5e841d92c.tif, last_error -> , all_parents -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434_20210602-224529.tif, driver -> GTiff, parentPath -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434_20210602-224529.tif, last_command -> gdalwarp -wo CUTLINE_ALL_TOUCHED=TRUE -cutline /tmp/raster_tmp/raster_tmp/10665217145723839054/raster_df965090_8cee_47ff_8cd2_2607ab42ebb1.shp -crop_to_cutline -of GTiff -co TILED=YES -co COMPRESS=DEFLATE))</td><td>9521508</td><td>AIAAAAMAAAABAAAABUEjJfQAAAAAQVzISAAAAAB/+AAAAAAAAEEjJfQAAAAAQVyteYAAAAB/+AAAAAAAAEEj/GgAAAAAQVyteYAAAAB/+AAAAAAAAEEj/GgAAAAAQVzISAAAAAB/+AAAAAAAAEEjJfQAAAAAQVzISAAAAAB/+AA= (truncated)</td><td>32603</td><td>false</td><td>AIAAAAMAAAABAAAABcBkNInVc4dmQFD0F0uTEjV/+AAAAAAAAMBkNJN/VewSQFDyp92IJV5/+AAAAAAAAMBkNKPnIA3wQFDyp+luiR1/+AAAAAAAAMBkNJo9Otk7QFD0F1fkZ0R/+AAAAAAAAMBkNInVc4dmQFD0F0uTEjV/+AA= (truncated)</td></tr><tr><td>608200678346588159</td><td>S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434</td><td>2021-06-02</td><td>B02</td><td>List(608200678346588159, SUkqAAgAAAATAAABAwABAAAAkAEAAAEBAwABAAAAgwAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/10665217145723839054/raster_e70befc7_95ad_4c82_9469_56d81fe52875.tif, last_error -> , all_parents -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434_20210602-224529.tif, driver -> GTiff, parentPath -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434_20210602-224529.tif, last_command -> gdalwarp -wo CUTLINE_ALL_TOUCHED=TRUE -cutline /tmp/raster_tmp/raster_tmp/10665217145723839054/raster_80ec47c4_03af_4e94_bc03_2ea79e26f8f8.shp -crop_to_cutline -of GTiff -co TILED=YES -co COMPRESS=DEFLATE))</td><td>9521508</td><td>AIAAAAMAAAABAAAABUEjJfQAAAAAQVzISAAAAAB/+AAAAAAAAEEjJfQAAAAAQVyteYAAAAB/+AAAAAAAAEEj/GgAAAAAQVyteYAAAAB/+AAAAAAAAEEj/GgAAAAAQVzISAAAAAB/+AAAAAAAAEEjJfQAAAAAQVzISAAAAAB/+AA= (truncated)</td><td>32603</td><td>false</td><td>AIAAAAMAAAABAAAABcBkLQ7b2wMOQFD2Caxbrzt/+AAAAAAAAMBkLwsyoR+aQFD2Taq1wwh/+AAAAAAAAMBkLvJQu6qRQFD2ay4K97N/+AAAAAAAAMBkLPXyK/ygQFD2Jy6mPOR/+AAAAAAAAMBkLQ7b2wMOQFD2Caxbrzt/+AA= (truncated)</td></tr><tr><td>608200678447251455</td><td>S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434</td><td>2021-06-02</td><td>B02</td><td>List(608200678447251455, SUkqAAgAAAATAAABAwABAAAAkQEAAAEBAwABAAAAgwAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/10665217145723839054/raster_3144e513_1b8f_4d39_9ef7_08ffb775af8d.tif, last_error -> , all_parents -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434_20210602-224529.tif, driver -> GTiff, parentPath -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434_20210602-224529.tif, last_com ...

# %% [markdown]
# _[3] For precise clipping we use `rst_clip` and the H3 tessellate fields._
#
# __Notes:__
#
# 1. For this, we use the approximate result first to avoid unnecessary comparisons.
# 1. We are testing the actual wkb_buffer on the tiles.
# 1. The results are the intersections.

# %%
display(
  for_clip_df
    .selectExpr("tile","cast(srid as integer) as srid","wkb_clip")
    .withColumn("geom_clip", mos.st_setsrid(mos.st_geomfromwkb("wkb_clip"), F.lit(4326)))
    .withColumn(
      "geom_clip",
      mos.st_transform("geom_clip", "srid")
    )
  .limit(10)
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>tile</th><th>srid</th><th>wkb_clip</th><th>geom_clip</th></tr></thead><tbody><tr><td>List(608200678145261567, SUkqAAgAAAATAAABAwABAAAAkAEAAAEBAwABAAAAgwAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/10665217145723839054/raster_46d610dd_9e9e_4607_870f_efb5e841d92c.tif, last_error -> , all_parents -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434_20210602-224529.tif, driver -> GTiff, parentPath -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434_20210602-224529.tif, last_command -> gdalwarp -wo CUTLINE_ALL_TOUCHED=TRUE -cutline /tmp/raster_tmp/raster_tmp/10665217145723839054/raster_df965090_8cee_47ff_8cd2_2607ab42ebb1.shp -crop_to_cutline -of GTiff -co TILED=YES -co COMPRESS=DEFLATE))</td><td>32603</td><td>AIAAAAMAAAABAAAABcBkNInVc4dmQFD0F0uTEjV/+AAAAAAAAMBkNJN/VewSQFDyp92IJV5/+AAAAAAAAMBkNKPnIA3wQFDyp+luiR1/+AAAAAAAAMBkNJo9Otk7QFD0F1fkZ0R/+AAAAAAAAMBkNInVc4dmQFD0F0uTEjV/+AA= (truncated)</td><td>List(5, 32603, List(List(List(641456.5512001769, 7525958.436283999), List(641542.5254612261, 7523458.552420029), List(641458.1401159156, 7523454.287995422), List(641372.24643011, 7525954.185014442), List(641456.5512001769, 7525958.436283999))), List(List()))</td></tr><tr><td>List(608200678346588159, SUkqAAgAAAATAAABAwABAAAAkAEAAAEBAwABAAAAgwAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/10665217145723839054/raster_e70befc7_95ad_4c82_9469_56d81fe52875.tif, last_error -> , all_parents -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434_20210602-224529.tif, driver -> GTiff, parentPath -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434_20210602-224529.tif, last_command -> gdalwarp -wo CUTLINE_ALL_TOUCHED=TRUE -cutline /tmp/raster_tmp/raster_tmp/10665217145723839054/raster_80ec47c4_03af_4e94_bc03_2ea79e26f8f8.shp -crop_to_cutline -of GTiff -co TILED=YES -co COMPRESS=DEFLATE))</td><td>32603</td><td>AIAAAAMAAAABAAAABcBkLQ7b2wMOQFD2Caxbrzt/+AAAAAAAAMBkLwsyoR+aQFD2Taq1wwh/+AAAAAAAAMBkLvJQu6qRQFD2ay4K97N/+AAAAAAAAMBkLPXyK/ygQFD2Jy6mPOR/+AAAAAAAAMBkLQ7b2wMOQFD2Caxbrzt/+AA= (truncated)</td><td>List(5, 32603, List(List(List(651097.5051120671, 7529898.17594578), List(648463.1831595813, 7530209.918991724), List(648579.3489100653, 7530417.769662811), List(651213.6440146172, 7530106.127562127), List(651097.5051120671, 7529898.17594578))), List(List()))</td></tr><tr><td>List(608200678447251455, SUkqAAgAAAATAAABAwABAAAAkQEAAAEBAwABAAAAgwAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/10665217145723839054/raster_3144e513_1b8f_4d39_9ef7_08ffb775af8d.tif, last_error -> , all_parents -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434_20210602-224529.tif, driver -> GTiff, parentPath -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434_20210602-224529.tif, last_command -> gdalwarp -wo CUTLINE_ALL_TOUCHED=TRUE -cutline /tmp/raster_tmp/raster_tmp/10665217145723839054/raster_79e945aa_4699_424a_89b6_2cb74d967a22.shp -crop_to_cutline -of GTiff -co TILED=YES -co COMPRESS=DEFLATE))</td><td>32603</td><td>AIAAAAMAAAABAAAABcBkLwsyoR+aQFD2Taq1wwh/+AAAAAAAAMBkMGOiPJReQFD2e7zBzmR/+AAAAAAAAMBkMHywGewsQFD2n+3/wVh/+AAAAAAAAMBkLvJQu6qRQFD2ay4 ...

# %%
clip_df = (
  for_clip_df
    .withColumn("geom_clip", mos.st_setsrid(mos.st_geomfromwkb("wkb_clip"), F.lit(4326)))
    .withColumn("geom_clip", mos.st_transform("geom_clip", F.expr("cast(srid as integer)")))
    .withColumn(
      "clipped_tile",
      F
        .when(col("is_core_clip"), col("tile"))
        .otherwise(mos.rst_clip("tile","geom_clip"))
    )
)
print(f"count? {clip_df.count():,}")
clip_df.limit(10).display()
# Out:
# count? 581
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>index_id</th><th>item_id</th><th>date</th><th>band_name</th><th>tile</th><th>size</th><th>bbox</th><th>srid</th><th>is_core_clip</th><th>wkb_clip</th><th>geom_clip</th><th>clipped_tile</th></tr></thead><tbody><tr><td>608200678145261567</td><td>S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434</td><td>2021-06-02</td><td>B02</td><td>List(608200678145261567, SUkqAAgAAAATAAABAwABAAAAkAEAAAEBAwABAAAAgwAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/10665217145723839054/raster_46d610dd_9e9e_4607_870f_efb5e841d92c.tif, last_error -> , all_parents -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434_20210602-224529.tif, driver -> GTiff, parentPath -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434_20210602-224529.tif, last_command -> gdalwarp -wo CUTLINE_ALL_TOUCHED=TRUE -cutline /tmp/raster_tmp/raster_tmp/10665217145723839054/raster_df965090_8cee_47ff_8cd2_2607ab42ebb1.shp -crop_to_cutline -of GTiff -co TILED=YES -co COMPRESS=DEFLATE))</td><td>9521508</td><td>AIAAAAMAAAABAAAABUEjJfQAAAAAQVzISAAAAAB/+AAAAAAAAEEjJfQAAAAAQVyteYAAAAB/+AAAAAAAAEEj/GgAAAAAQVyteYAAAAB/+AAAAAAAAEEj/GgAAAAAQVzISAAAAAB/+AAAAAAAAEEjJfQAAAAAQVzISAAAAAB/+AA= (truncated)</td><td>32603</td><td>false</td><td>AIAAAAMAAAABAAAABcBkNInVc4dmQFD0F0uTEjV/+AAAAAAAAMBkNJN/VewSQFDyp92IJV5/+AAAAAAAAMBkNKPnIA3wQFDyp+luiR1/+AAAAAAAAMBkNJo9Otk7QFD0F1fkZ0R/+AAAAAAAAMBkNInVc4dmQFD0F0uTEjV/+AA= (truncated)</td><td>List(5, 32603, List(List(List(641456.5512001769, 7525958.436283999), List(641542.5254612261, 7523458.552420029), List(641458.1401159156, 7523454.287995422), List(641372.24643011, 7525954.185014442), List(641456.5512001769, 7525958.436283999))), List(List()))</td><td>List(608200678145261567, SUkqAAgAAAATAAABAwABAAAAFAAAAAEBAwABAAAAgwAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/1094365353429733265/raster_89342fd3_a262_47f7_bb04_1f252e9d25fc.tif, last_error -> , all_parents -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434_20210602-224529.tif, driver -> GTiff, parentPath -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434_20210602-224529.tif, last_command -> gdalwarp -wo CUTLINE_ALL_TOUCHED=TRUE -cutline /tmp/raster_tmp/raster_tmp/1094365353429733265/raster_224463f4_583a_4c02_84bd_6dcb6bc46714.shp -crop_to_cutline -of GTiff -co TILED=YES -co COMPRESS=DEFLATE))</td></tr><tr><td>608200678346588159</td><td>S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434</td><td>2021-06-02</td><td>B02</td><td>List(608200678346588159, SUkqAAgAAAATAAABAwABAAAAkAEAAAEBAwABAAAAgwAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/10665217145723839054/raster_e70befc7_95ad_4c82_9469_56d81fe52875.tif, last_error -> , all_parents -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434_20210602-224529.tif, driver -> GTiff, parentPath -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T03WXR_20210603T153434_20210602-224529.tif, last_command -> gdalwarp -wo CUTLINE_ALL_TOUCHED=TRUE -cutline /tmp/raster_tmp/raster_tmp/10665217145723839054/raster_80ec47c4_03af_4e94_bc03_2ea79e26f8f8.shp -crop_to_cutline -of GTiff -co TILED=YES -co COMPRESS=DEFLATE))</td><td>9521508</td><td>AIAAAAMAAAABAAAAB ...

# %%
display(
  clip_df
    .groupBy("index_id")
      .count()
    .orderBy(F.desc("count"))
  .limit(10)
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>index_id</th><th>count</th></tr></thead><tbody><tr><td>608199378196234239</td><td>5</td></tr><tr><td>608199378263343103</td><td>5</td></tr><tr><td>608199345296113663</td><td>5</td></tr><tr><td>608199345329668095</td><td>4</td></tr><tr><td>608216514478211071</td><td>4</td></tr><tr><td>608216513706459135</td><td>4</td></tr><tr><td>608199617657438207</td><td>4</td></tr><tr><td>608199509008187391</td><td>3</td></tr><tr><td>608199303705395199</td><td>3</td></tr><tr><td>608216536221483007</td><td>3</td></tr></tbody></table></div>

# %% [markdown]
# Let's look at one of the clipped tiles.

# %%
library.plot_raster(clip_df.first()["tile"]["raster"])

# %% [markdown]
# ## Merge Rasters [H3]
#
# > Here we show merging per H3 cell. We also write this out to delta for any follow on operations.

# %%
merge_h3_df = None
merge_h3_tbl_name = "band_b02_h3_merge"
if not spark.catalog.tableExists(merge_h3_tbl_name):
  (
    clip_df
      .groupBy("index_id")
        .agg(
          F.count(F.lit(1)).alias("cnt"),
          mos.rst_combineavg_agg("tile").alias("tile")
        )
      .write
        .saveAsTable(merge_h3_tbl_name)
  )
sql(f"""OPTIMIZE {merge_h3_tbl_name} ZORDER BY (index_id)""")
merge_h3_df = spark.table(merge_h3_tbl_name)
print(f"count? {merge_h3_df.count():,}")
merge_h3_df.limit(10).display()
# Out:
# count? 326
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>index_id</th><th>cnt</th><th>tile</th></tr></thead><tbody><tr><td>608200703495634943</td><td>2</td><td>List(608200703495634943, SUkqAAgAAAATAAABAwABAAAAkgEAAAEBAwABAAAAiQAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/731937043526912377/raster_25d9de7c_4d8b_48b8_8eb6_0fe6fb887014.tif, last_error -> , all_parents -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T04WDV_20210603T143924_20210602-224529.tif, driver -> GTiff, parentPath -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T04WDV_20210603T143924_20210602-224529.tif, last_command -> gdal_translate -of GTiff -co TILED=YES -co COMPRESS=DEFLATE))</td></tr><tr><td>608216513454800895</td><td>3</td><td>List(608216513454800895, SUkqAAgAAAATAAABAwABAAAAfwEAAAEBAwABAAAAggAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/14617276072549089435/raster_ab14a36d_c4cf_4dd3_b5bd_773aa99e138f.tif, last_error -> , all_parents -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T04WDA_20210603T144008_20210602-224529.tif, driver -> GTiff, parentPath -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T04WDA_20210603T144008_20210602-224529.tif, last_command -> gdal_translate -of GTiff -co TILED=YES -co COMPRESS=DEFLATE))</td></tr><tr><td>608216515367403519</td><td>1</td><td>List(608216515367403519, SUkqAAgAAAATAAABAwABAAAAewEAAAEBAwABAAAAfwAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/848155139835258333/raster_4f60a0e1_7d48_4f0e_b5a3_3e465282d397.tif, last_error -> , all_parents -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T04WDA_20210603T144008_20210602-224529.tif, driver -> GTiff, parentPath -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T04WDA_20210603T144008_20210602-224529.tif, last_command -> gdalwarp -wo CUTLINE_ALL_TOUCHED=TRUE -cutline /tmp/raster_tmp/raster_tmp/848155139835258333/raster_c6a107a9_9c48_4698_b91a_e933dd85f856.shp -crop_to_cutline -of GTiff -co TILED=YES -co COMPRESS=DEFLATE))</td></tr><tr><td>608199689078046719</td><td>1</td><td>List(608199689078046719, SUkqAAgAAAATAAABAwABAAAAfQEAAAEBAwABAAAAgQAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/9886727174844583356/raster_66dfffff_ffb4_4940_80b6_b3dbf46fb966.tif, last_error -> , all_parents -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T04WDA_20210603T144008_20210602-224529.tif, driver -> GTiff, parentPath -> /Volumes/milos_dev/mosaic_dev_eo_alaska/data/data/alaska/B02/B02_S2B_MSIL2A_20210602T224529_R101_T04WDA_20210603T144008_20210602-224529.tif, last_command -> gdalwarp -wo CUTLINE_ALL_TOUCHED=TRUE -cutline /tmp/raster_tmp/raster_tmp/9886727174844583356/raster_73b39001_48ed_4ec8_a487_0267ebd14fa8.shp -crop_to_cutline -of GTiff -co TILED=YES -co COMPRESS=DEFLATE))</td></tr><tr><td>608200713998172159</td><td>2</td><td>List(608200713998172159, SUkqAAgAAAATAAABAwABAAAAkgEAAAEBAwABAAAAiwAAAAIBAwABAAAAEAAAAAMBAwABAAAACAAAAAYBAwABAAAAAQAAABUBAwABAAAAAQAAABwBAwABAAAAAQAAAD0BAwABAAAAAQAAAEIBAwABAAAAAAEAAEMBAwABAAAAAAE= (truncated), Map(path -> /tmp/raster_tmp/raster_tmp/15377812765596768308/raster_1fd2d367_223b_4302_a4e4_e2fc23d1fd ...

# %%
library.plot_raster(merge_h3_df.first()["tile"]["raster"])

# %% [markdown]
# ## Merge the Entire Corridor?
#
# > A quick test of the combined size of per H3 rasters in `merge_h3_df` shows the __resulting size would be on the order of 90MB if we attempted to merge further__ - again, this can get unwieldly, so be careful.

# %%
display(
  merge_h3_df
    .select(mos.rst_memsize("tile").alias("memsize"))
    .groupBy()
      .agg(
        F.sum("memsize").alias("memsum")
      )
    .withColumn("memsum_kb", (col("memsum") / F.lit(1024)))
    .withColumn("memsum_mb", (col("memsum_kb") / F.lit(1024)))
    .selectExpr("format_number(memsum_mb,0) as memsum_mb_display")
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>memsum_mb_display</th></tr></thead><tbody><tr><td>16</td></tr></tbody></table></div>

# %%
CORRIDOR_DIR = "/Volumes/milos_dev/mosaic_dev_eo_alaska/data/corridor"
os.environ['CORRIDOR_DIR'] = CORRIDOR_DIR

dbutils.fs.mkdirs(CORRIDOR_DIR)
print(f"CORRIDOR_DIR: '{CORRIDOR_DIR}'")
# Out:
# CORRIDOR_DIR: '/Volumes/milos_dev/mosaic_dev_eo_alaska/data/corridor'

# %% [markdown]
# ### [1] Write In-Memory Rasters
#
# > Following from the UDF examples for Rasterio in Mosaic [docs](https://databrickslabs.github.io/mosaic/api/rasterio-udfs.html#udf-example-for-writing-raster-files-to-disk), we wil show how to write out the rasters in `merge_h3_df`. Again, this is __1,300 files totalling around 90MBs__ as-is which is not too large, and we perform the writes using a Spark UDF. Also, we add the [recommended Spark configs](https://databrickslabs.github.io/mosaic/api/rasterio-udfs.html#intro) (beyond ones already applied at top of notebook).

# %%
spark.conf.set("spark.sql.execution.arrow.enabled", "true")
spark.conf.set("spark.sql.execution.arrow.maxRecordsPerBatch", "1024")
spark.conf.set("spark.sql.execution.arrow.fallback.enabled", "true")

# %%
@udf("string")
def write_tif(raster, file_id, parent_dir):
  from pathlib import Path
  import os
  import shutil
  import tempfile
  
  Path(parent_dir).mkdir(parents=True, exist_ok=True)
  fuse_path = f"{parent_dir}/h3_{file_id}.tif"
  if not os.path.exists(fuse_path):
    with tempfile.NamedTemporaryFile() as tmpfile:
      tmpfile.write(raster)
      shutil.copyfile(tmpfile.name, fuse_path)
  return fuse_path

# %%
corridor_df = (
  merge_h3_df
    .select(
      "tile.raster", 
      col("index_id").alias("file_id"),
      F.lit(f"{CORRIDOR_DIR}/band_b02").alias("parent_dir")
    )
    .repartition(128, "file_id")
    .withColumn(
      "tiff_out",
      write_tif("raster", "file_id", "parent_dir")
    )
)

out_cnt = corridor_df.groupBy("tiff_out").count().count() # <- force full execution
print(f"count? {out_cnt:,}")
# corridor_df.limit(1).display()
# Out:
# count? 326

# %%
# %sh
echo "num files? $(ls -1 $CORRIDOR_DIR/band_b02 | wc -l)"
ls -lh $CORRIDOR_DIR/band_b02 | head -5
echo "..."
ls -lh $CORRIDOR_DIR/band_b02 | tail -5
# Out:
# num files? 326
# total 16M
# -rwxrwxrwx 1 nobody nogroup  53K Jun  4 18:10 h3_608199269060444159.tif
# -rwxrwxrwx 1 nobody nogroup  53K Jun  4 18:10 h3_608199269093998591.tif
# -rwxrwxrwx 1 nobody nogroup  51K Jun  4 18:10 h3_608199269144330239.tif
# -rwxrwxrwx 1 nobody nogroup  47K Jun  4 18:10 h3_608199269161107455.tif
# ...
# -rwxrwxrwx 1 nobody nogroup  62K Jun  4 18:10 h3_608216532094287871.tif
# -rwxrwxrwx 1 nobody nogroup  61K Jun  4 18:10 h3_608216532111065087.tif
# -rwxrwxrwx 1 nobody nogroup  60K Jun  4 18:10 h3_608216536187928575.tif
# -rwxrwxrwx 1 nobody nogroup  67K Jun  4 18:10 h3_608216536204705791.tif
# -rwxrwxrwx 1 nobody nogroup  61K Jun  4 18:10 h3_608216536221483007.tif

# %%
library.plot_file("/Volumes/milos_dev/mosaic_dev_eo_alaska/data/corridor/band_b02/h3_608216536204705791.tif")

# %% [markdown]
# ### [2] Perform Corridor Merge
#
# > We will iterate over the persisted rasters for the corridor per each each H3 cell (from [1]) and generate a single raster. For this example, we follow steps from this [medium](https://medium.com/spatial-data-science/how-to-mosaic-merge-raster-data-in-python-fb18e44f3c8) post.

# %% [markdown]
# > [a] Let us first import the libraries and create the output folder with Python path lib.

# %%
from rasterio.plot import show
from rasterio.merge import merge
import rasterio as rio
from pathlib import Path

raster_path = Path(f'{CORRIDOR_DIR}/band_b02')
out_dir_fuse = f'{CORRIDOR_DIR}/out'
out_dir_local = 'out'
out_path_local = f'{out_dir_local}/mosaic_corridor_b02.tif'

Path(out_dir_fuse).mkdir(parents=True, exist_ok=True)
Path(out_dir_local).mkdir(parents=True, exist_ok=True)

print(f"raster_path: '{raster_path}', out_path_local: '{out_path_local}, out_dir_fuse? '{out_dir_fuse}'")
# Out:
# raster_path: '/Volumes/milos_dev/mosaic_dev_eo_alaska/data/corridor/band_b02', out_path_local: 'out/mosaic_corridor_b02.tif, out_dir_fuse? '/Volumes/milos_dev/mosaic_dev_eo_alaska/data/corridor/out'

# %% [markdown]
# > [b] Now we iterate over the available .tif files in the data folder. We will merge all files in this data folder and create a mosaic from them. We also create an empty list to hold the files in the data folder.

# %%
raster_to_mosiac = []
raster_files = list(raster_path.iterdir())
num_files = len(raster_files)
print(f"num rasters to merge? {num_files:,}")
# Out:
# num rasters to merge? 326

# %% [markdown]
# > [c] We then loop through the raster files, open them with rasterio and append them to the raster_to_mosiac list we created above. __Note: This took ~6 minutes running on the driver.__

# %%
for i,p in enumerate(raster_files):
  try:
    if (i > 0) and (i % 10 == 0):
      print(f"...{round((i/num_files) * 100, 2)}%")
    raster_to_mosiac.append(rio.open(p))
  except Exception as e:
    print(f"issue with '{p.name}'", e)
    pass
# Out:
# ...3.07%
# ...6.13%
# ...9.2%
# ...12.27%
# ...15.34%
# ...18.4%
# ...21.47%
# ...24.54%
# ...27.61%
# ...30.67%
# ...33.74%
# ...36.81%
# ...39.88%
# issue with 'h3_608199688323071999.tif' '/Volumes/milos_dev/mosaic_dev_eo_alaska/data/corridor/band_b02/h3_608199688323071999.tif' not recognized as being in a supported file format.
# ...42.94%
# ...46.01%
# ...49.08%
# issue with 'h3_608199722045276159.tif' '/Volumes/milos_dev/mosaic_dev_eo_alaska/data/corridor/band_b02/h3_608199722045276159.tif' not recognized as being in a supported file format.
# ...52.15%
# ...55.21%
# ...58.28%
# ...61.35%
# ...64.42%
# ...67.48%
# ...70.55%
# ...73.62%
# issue with 'h3_608200741647024127.tif' '/Volumes/milos_dev/mosaic_dev_eo_alaska/data/corridor/band_b02/h3_608200741647024127.tif' not recognized as being in a supported file format.
# ...76.69%
# ...79.75%
# ...82.82%
# ...85.89%
# ...88.96%
# ...92.02%
# ...95.09%
# ...98.16%

# %% [markdown]
# > [d] From this stage on, it is easy. We use the merge() method from rasterio to create the mosaic. We also create the output transformation parameters to use later. __Note: This took ~3 minutes running on the driver.__

# %%
mosaic, output = merge(raster_to_mosiac)

# %%
# Out:
# array([[[65535, 65535, 65535, ..., 65535, 65535, 65535],
#         [65535, 65535, 65535, ..., 65535, 65535, 65535],
#         [65535, 65535, 65535, ..., 65535, 65535, 65535],
#         ...,
#         [65535, 65535, 65535, ..., 65535, 65535, 65535],
#         [65535, 65535, 65535, ..., 65535, 65535, 65535],
#         [65535, 65535, 65535, ..., 65535, 65535, 65535]]], dtype=uint16)

# %% [markdown]
# > [e] Now, we copy the raster's metadata and update it to match the height and width of the mosaic.

# %%
output_meta = raster_to_mosiac[0].meta.copy()
output_meta.update(
    {
        "driver": "GTiff",
        "height": mosaic.shape[1],
        "width": mosaic.shape[2],
        "transform": output,
        "dtype": "uint16",
        "count": 1,
        "crs": "EPSG:4326",
        "nodata": 65535,
        "tiled": True,
        "blockxsize": 512,
        "blockysize": 512,
        "compress": "lzw",
        "BIGTIFF": "YES"
    }
)
output_meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'uint16',
#  'nodata': 65535,
#  'width': 48833,
#  'height': 10243,
#  'count': 1,
#  'crs': 'EPSG:4326',
#  'transform': Affine(0.00016436006108255682, 0.0, -161.7296213067411,
#         0.0, -0.00016436006108251072, 67.88129887474551),
#  'tiled': True,
#  'blockxsize': 512,
#  'blockysize': 512,
#  'compress': 'lzw',
#  'BIGTIFF': 'YES'}

# %% [markdown]
# > [f] Next, we write the mosaiced file in a local folder. __Note: The total size is 2.2G__

# %%
with rio.open(out_path_local, 'w', **output_meta) as m:
    m.write(mosaic)

# %%
# %sh ls -lh out
# Out:
# total 24M
# -rwxrwxrwx 1 root root 24M Jun  4 18:31 mosaic_corridor_b02.tif

# %% [markdown]
# > [g] let's render the mosaic for the corridor. __Hint: you can right click and 'open in new tab' to be able to zoom in more.__

# %%
# - uncomment to render from local file (note: 2.2 GBs)
library.plot_file(out_path_local, fig_w=20, fig_h=12)

# %% [markdown]
# _This is a 2.2GB file. Here are screenshots of what it looks like when viewed in QGIS, showing 2 levels of zoom._

# %%
displayHTML("""<img src="data:image/jpeg;base64,..." width="100%">""")
# Out:
# <img src="data:image/jpeg;base64,..." width="100%">

# %%
displayHTML("""<img src="data:image/jpeg;base64,..." width="100%">""")
# Out:
# <img src="data:image/jpeg;base64,..." width="100%">

# %% [markdown]
# > [h] once satisfied, we can copy up to out_dir_fuse.

# %%
# %sh
cp out/mosaic_corridor_b02.tif $CORRIDOR_DIR/out
ls -lh $CORRIDOR_DIR/out
# Out:
# total 2.2G
# -rwxrwxrwx 1 root root 2.2G Dec 29 04:53 mosaic_corridor_b02.tif

# %%
# - this is faster from the local file
#library.plot_file(f"{CORRIDOR_DIR_FUSE}/out/mosaic_corridor_b02.tif", fig_w=16, fig_h=16)
