# %% [markdown]
# # Product-native spatial SQL
#
# > Databricks has 75+ Spatial SQL expressions under development + GEOMETRY / GEOGRAPHY types, currently in preview. This is a quick demo of some of those functions using a small [strava](https://www.strava.com/) dataset.
#
# __Note: Requires that you are enrolled in the private preview(s) to execute and running on DBR 16.4+ with Photon.__
#
# ---
# __Original Author:__ Stuart Lynn | __Maintainer:__ Michael Johns | _Last Updated:_ 14 May 2025

# %%
# %python
# %pip install geopandas folium mapclassify --quiet
# Out:
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# %python
import os
import geopandas as gpd
import pyspark.databricks.sql.functions as DBF
import pyspark.sql.functions as F

# %% [markdown]
# ## What `ST_` functions are available?

# %%
# %sql
SHOW FUNCTIONS LIKE 'ST_*'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>function</th></tr></thead><tbody><tr><td>st_addpoint</td></tr><tr><td>st_area</td></tr><tr><td>st_asbinary</td></tr><tr><td>st_asewkb</td></tr><tr><td>st_asewkt</td></tr><tr><td>st_asgeojson</td></tr><tr><td>st_astext</td></tr><tr><td>st_aswkb</td></tr><tr><td>st_aswkt</td></tr><tr><td>st_buffer</td></tr><tr><td>st_centroid</td></tr><tr><td>st_concavehull</td></tr><tr><td>st_contains</td></tr><tr><td>st_convexhull</td></tr><tr><td>st_covers</td></tr><tr><td>st_difference</td></tr><tr><td>st_dimension</td></tr><tr><td>st_disjoint</td></tr><tr><td>st_distance</td></tr><tr><td>st_distancesphere</td></tr><tr><td>st_distancespheroid</td></tr><tr><td>st_endpoint</td></tr><tr><td>st_envelope</td></tr><tr><td>st_envelope_agg</td></tr><tr><td>st_equals</td></tr><tr><td>st_flipcoordinates</td></tr><tr><td>st_geogarea</td></tr><tr><td>st_geogfromgeojson</td></tr><tr><td>st_geogfromtext</td></tr><tr><td>st_geogfromwkb</td></tr><tr><td>st_geogfromwkt</td></tr><tr><td>st_geoglength</td></tr><tr><td>st_geogperimeter</td></tr><tr><td>st_geohash</td></tr><tr><td>st_geometryn</td></tr><tr><td>st_geometrytype</td></tr><tr><td>st_geomfromewkb</td></tr><tr><td>st_geomfromgeohash</td></tr><tr><td>st_geomfromgeojson</td></tr><tr><td>st_geomfromtext</td></tr><tr><td>st_geomfromwkb</td></tr><tr><td>st_geomfromwkt</td></tr><tr><td>st_intersection</td></tr><tr><td>st_intersects</td></tr><tr><td>st_isempty</td></tr><tr><td>st_isvalid</td></tr><tr><td>st_length</td></tr><tr><td>st_m</td></tr><tr><td>st_makeline</td></tr><tr><td>st_makepolygon</td></tr><tr><td>st_multi</td></tr><tr><td>st_ndims</td></tr><tr><td>st_npoints</td></tr><tr><td>st_numgeometries</td></tr><tr><td>st_perimeter</td></tr><tr><td>st_point</td></tr><tr><td>st_pointfromgeohash</td></tr><tr><td>st_pointn</td></tr><tr><td>st_removepoint</td></tr><tr><td>st_reverse</td></tr><tr><td>st_rotate</td></tr><tr><td>st_scale</td></tr><tr><td>st_setpoint</td></tr><tr><td>st_setsrid</td></tr><tr><td>st_simplify</td></tr><tr><td>st_srid</td></tr><tr><td>st_startpoint</td></tr><tr><td>st_touches</td></tr><tr><td>st_transform</td></tr><tr><td>st_translate</td></tr><tr><td>st_union</td></tr><tr><td>st_union_agg</td></tr><tr><td>st_within</td></tr><tr><td>st_x</td></tr><tr><td>st_xmax</td></tr><tr><td>st_xmin</td></tr><tr><td>st_y</td></tr><tr><td>st_ymax</td></tr><tr><td>st_ymin</td></tr><tr><td>st_z</td></tr><tr><td>st_zmax</td></tr><tr><td>st_zmin</td></tr></tbody></table></div>

# %% [markdown]
# ## What is the definition of a given `ST_` function?

# %%
# %sql
DESCRIBE FUNCTION EXTENDED st_buffer
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>function_desc</th></tr></thead><tbody><tr><td>Function: st_buffer</td></tr><tr><td>Class: com.databricks.sql.catalyst.expressions.st.ST_Buffer</td></tr><tr><td>Usage: st_buffer(geo, radius) - Returns the buffer of the input geometry using the specified radius.</td></tr><tr><td>Extended Usage:
#     Arguments:
#       * geo - A GEOMETRY value, or a STRING value in WKT or GeoJSON format, or a BINARY value in WKB or EWKB format representing a GEOMETRY value.
#       * radius - Radius of the buffer. The unit of the radius are those of the coordinate reference system of the geometry.
#
#     Examples:
#       > SELECT st_astext(st_buffer('POINT(0 0)', 1), 3);
#        POLYGON((1 0,0.981 -0.195,0.924 -0.383,0.831 -0.556,0.707 -0.707,0.556 -0.831,0.383 -0.924,0.195 -0.981,6.12e-17 -1,-0.195 -0.981,-0.383 -0.924,-0.556 -0.831,-0.707 -0.707,-0.831 -0.556,-0.924 -0.383,-0.981 -0.195,-1 -1.22e-16,-0.981 0.195,-0.924 0.383,-0.831 0.556,-0.707 0.707,-0.556 0.831,-0.383 0.924,-0.195 0.981,-1.84e-16 1,0.195 0.981,0.383 0.924,0.556 0.831,0.707 0.707,0.831 0.556,0.924 0.383,0.981 0.195,1 0))
#
#     Since: 3.5.0
# </td></tr></tbody></table></div>

# %% [markdown]
# ## Construct a geometry
#
# > In the preview (as of DBR 16.4), GEOMETRY / GEOGRAPHY types are not displayed (show '[object Object...]'), so we can convert to WKT when rendering. This will be handled by product in the future.

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW pois AS
WITH park AS (
  SELECT
    "POINT (-0.000767 51.477798)" AS wkt
)
SELECT
  "General Wolfe" AS poi_name,
  ST_GEOMFROMTEXT(wkt, 4326) AS geom,
  wkt
FROM
  park;

SELECT
  *
FROM
  pois;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>poi_name</th><th>geom</th><th>wkt</th></tr></thead><tbody><tr><td>General Wolfe</td><td>Map(bytes -> AQAAAOYQAAAAAAAAXYlA9Q8iSb8PDCB8KL1JQA==)</td><td>POINT (-0.000767 51.477798)</td></tr></tbody></table></div>

# %% [markdown]
# See also:
# - st_geomfromgeojson
# - st_geomfromwkb
# - st_makeline
# - st_makepolygon
# - st_point

# %% [markdown]
# ## Quick inspection of our data

# %%
# %python
displayHTML("""<img src="data:image/jpg;base64,..." width="25%">""")
# Out:
# <img src="data:image/jpg;base64,..." width="25%">

# %%
# %python
## -- uncomment to run in databricks
# _tbl = spark.table("pois").drop("geom")
# gs = gpd.GeoSeries.from_wkt(_tbl.toPandas()["wkt"], crs=4326)
# pdf = _tbl.toPandas()
# pdf["geometry"] = gs
# gdf = gpd.GeoDataFrame(pdf, geometry="geometry")
# gdf.explore()

# %%
# %python
displayHTML("""<img src="data:image/jpg;base64,..." width="50%">""")
# Out:
# <img src="data:image/jpg;base64,..." width="50%">

# %% [markdown]
# ## Coordinate reprojection
#
# > Starting from British National Grid [2700], will reproject to WGS84 [4326].

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW areas AS
WITH bng_poly AS (
  SELECT
    "Polygon ((539080.74751770845614374 177832.91306236910168082, 538767.14163828617893159 177684.27982682932633907, 538727.31745586439501494 177673.18859504663851112, 538621.84594145440496504 177616.95230604690732434, 538490.54813365358859301 177526.66315907711395994, 538461.83612446254119277 177475.85392566624796018, 538466.63019655959215015 177422.62076200800947845, 538477.19970560283400118 177402.8968720713746734, 538515.22874738450627774 177357.2380391139886342, 538559.66927617788314819 177321.75953704561106861, 538577.28611368732526898 177288.88596884300932288, 538600.60744349961169064 177169.44750937586650252, 538625.09037635033018887 177130.08916657301597297, 538648.84648620593361557 177117.39449425134807825, 538700.42835317435674369 177065.43241473636589944, 538749.9418425892945379 176966.71622413786826655, 538798.00173944456037134 176921.32852166821248829, 538822.66879277874249965 176875.30273452715482563, 538902.44626043341122568 176770.73795371776213869, 538981.31591152853798121 176699.5043591340072453, 539001.45930460619274527 176696.71848380187293515, 539100.53612874797545373 176742.78883285738993436, 539180.19766917137894779 176764.98013099154923111, 539311.5966025177622214 176851.966067130852025, 539377.52282120834570378 176887.12700300174765289, 539480.11801618535537273 176926.62874431553063914, 539529.15005440777167678 176967.99971074820496142, 539575.38804935966618359 176989.28076505078934133, 539581.70609962672460824 177002.79634332819841802, 539647.44598334014881402 177044.62610658182529733, 539653.76379332377109677 177058.14164582575904205, 539649.6901807285612449 177084.71425135689787567, 539624.83299735363107175 177137.40057581866858527, 539555.43555313709657639 177228.89047401363495737, 539520.28041602007579058 177291.29953734739683568, 539471.85091075743548572 177350.00893362716306001, 539458.30143866187427193 177356.30838098999811336, 539392.25132515386212617 177447.88782484497642145, 539289.26398220960982144 177545.12575660482980311, 539223.31043143896386027 177633.37107035593362525, 539178.77629905252251774 177672.17467219801619649, 539140.10464662709273398 177741.15433048742124811, 539123.03277574293315411 177754.02790662919869646, 539074.24719945201650262 177826.0654000723734498, 539080.74751770845614374 177832.91306236910168082))" AS wkt_27700
)
SELECT
  "Greenwich Park" AS area_name,
  ST_GEOMFROMTEXT(wkt_27700, 27700) AS geom_27700,
  ST_GEOMFROMTEXT(wkt_4326, 4326) AS geom_4326,
  wkt_27700,
  wkt_4326
FROM
  (
    SELECT
      wkt_27700,
      ST_ASTEXT(ST_TRANSFORM(ST_SETSRID(ST_GEOMFROMTEXT(wkt_27700), 27700), 4326)) AS wkt_4326
    FROM
      bng_poly
  );

SELECT
  * EXCEPT(geom_27700, geom_4326)
FROM
  areas;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
# %%
# %python
displayHTML("""<img src="data:image/jpg;base64,..." width="25%">""")
# Out:
# <img src="data:image/jpg;base64,..." width="25%">

# %%
# %python
## -- uncomment to run in databricks
# _tbl = spark.table("areas").drop("geom_27700", "geom_4326")
# gs = gpd.GeoSeries.from_wkt(_tbl.toPandas()["wkt_4326"], crs=4326)
# pdf = _tbl.toPandas()
# pdf["geometry"] = gs
# gdf = gpd.GeoDataFrame(pdf, geometry="geometry")
# gdf.explore()

# %% [markdown]
# ## Compute spatial measures

# %%
# %sql
SELECT 
  area_name,
  ST_AREA(geom_27700) AS geom_area_m, --cartesian area, metres
  ST_AREA(geom_4326) AS geom_area_deg, --cartesian area, degrees
  ST_GEOGAREA(wkt_4326) AS geog_area_m --geodesic area (assumes WGS84)
FROM
  areas
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>area_name</th><th>geom_area_m</th><th>geom_area_deg</th><th>geog_area_m</th></tr></thead><tbody><tr><td>Greenwich Park</td><td>766319.4734127964</td><td>9.916705397211623E-5</td><td>766526.0275760443</td></tr></tbody></table></div>

# %% [markdown]
# ### Point-in-poly join

# %%
# %sql
SELECT
  a.area_name,
  p.poi_name,
  ST_INTERSECTS(a.geom_4326, p.geom) AS intersects
FROM areas a , pois p
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>area_name</th><th>poi_name</th><th>intersects</th></tr></thead><tbody><tr><td>Greenwich Park</td><td>General Wolfe</td><td>true</td></tr></tbody></table></div>

# %% [markdown]
# ### Apply an index to the data
#
# > In more scaled uses, you would persist the table instead of making it a temporary view.
#
# __Note:__ H3 remains a great pattern for scaled indexing (among other benefits), but want to highlight that Databricks is [WIP] on OOTB spatial join performance without requiring H3.

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIEW indexed_poi AS
SELECT
  *,
  H3_POINTASH3(wkt, 9) AS h3
FROM pois;

SELECT * FROM indexed_poi;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>poi_name</th><th>geom</th><th>wkt</th><th>h3</th></tr></thead><tbody><tr><td>General Wolfe</td><td>Map(bytes -> AQAAAOYQAAAAAAAAXYlA9Q8iSb8PDCB8KL1JQA==)</td><td>POINT (-0.000767 51.477798)</td><td>617438095264448511</td></tr></tbody></table></div>

# %%
# %python
displayHTML("""<img src="data:image/jpg;base64,..." width="25%">""")
# Out:
# <img src="data:image/jpg;base64,..." width="25%">

# %%
# %python
## -- uncomment to run in databricks
# indexed_point_pdf = (
#   spark.table("indexed_poi")
#   .drop("geom")
#   .withColumn("h3_geom", DBF.h3_boundaryaswkt("h3"))
#   ).toPandas()
# indexed_point_pdf["geometry"] = gpd.GeoSeries.from_wkt(indexed_point_pdf["wkt"], crs=4326)
# indexed_point_pdf["h3_geometry"] = gpd.GeoSeries.from_wkt(indexed_point_pdf["h3_geom"], crs=4326)
# m = gpd.GeoDataFrame(indexed_point_pdf, geometry="geometry").explore(zoom_start=16)
# gpd.GeoDataFrame(indexed_point_pdf, geometry="h3_geometry").explore(m=m)

# %%
# %sql
CREATE OR REPLACE TEMPORARY VIE
482980311, 539223.31043143896386027 177633.37107035593362525, 539178.77629905252251774 177672.17467219801619649, 539140.10464662709273398 177741.15433048742124811, 539123.03277574293315411 177754.02790662919869646, 539074.24719945201650262 177826.0654000723734498, 539080.74751770845614374 177832.91306236910168082))</td><td>POLYGON((0.00157091871565662 51.4823581757063,-0.00300076771977233 51.4810994655394,-0.00357824390108515 51.481009556341,-0.00511818038460091 51.4805300376225,-0.0070431009889944 51.4797508089517,-0.00747620812498113 51.4793012478932,-0.00742808510986897 51.4788217112132,-0.007283716064539 51.4786418836584,-0.00675436289833375 51.4782222832731,-0.0061287637019089 51.477892594548,-0.00588814862635841 51.4775928754573,-0.00559941053569891 51.4765138704233,-0.00526254942993223 51.4761541964063,-0.0049256883241619 51.4760343044371,-0.00420384309751426 51.4755547334091,-0.00353012088597662 51.4746555241417,-0.00285639867444098 51.474235887084,-0.00251953756867087 51.4738162461661,-0.00141270822114509 51.4728570524291,-0.000305878873620088 51.4721975950357,-1.71407829607705e-05 51.4721676194731,0.00142654967033401 51.4725573002502,0.00258150203296656 51.4727371517939,0.00450642263736038 51.4734865255939,0.00546888293955603 51.4737862716671,0.00696069640795617 51.4741159900728,0.00768254163460773 51.4744756801611,0.00835626384614114 51.4746555241417,0.0084525098763612 51.4747754197348,0.00941497017855775 51.4751351046235,0.00951121620877622 51.4752549989561,0.00946309319366596 51.4754947866761,0.00912623208789595 51.4759743583344,0.00816377178570156 51.4768135966042,0.00768254163460448 51.477383070922,0.00700881942306481 51.4779225663488,0.00681632736262725 51.4779825098912,0.00590199007554085 51.47882 ...

# %%
# %python
displayHTML("""<img src="data:image/jpg;base64,..." width="25%">""")
# Out:
# <img src="data:image/jpg;base64,..." width="25%">

# %%
# %python
## -- uncomment to run in databricks
# indexed_areas_pdf = (
#   spark.table("indexed_areas").select("wkt_4326", "chip_wkt")
#   ).toPandas()
# indexed_areas_pdf["h3_geometry"] = gpd.GeoSeries.from_wkt(indexed_areas_pdf["chip_wkt"], crs=4326)
# gpd.GeoDataFrame(indexed_areas_pdf, geometry="h3_geometry").explore()

# %% [markdown]
# ### Indexed join
#
# > Make use of the H3 cellids to avoid cross-joins.
#
# __Note:__ Databricks is implementing OOTB spatial performance to auto-handle indexing; meanwhile, customers still need to reason about it.

# %%
# %sql
SELECT
  a.area_name,
  p.poi_name
FROM indexed_areas a
  INNER JOIN indexed_poi p
  ON a.cellid = p.h3
WHERE
  a.core OR ST_INTERSECTS(ST_GEOMFROMWKB(a.chip, 4326), p.geom)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>area_name</th><th>poi_name</th></tr></thead><tbody><tr><td>Greenwich Park</td><td>General Wolfe</td></tr></tbody></table></div>

# %% [markdown]
# ### Doing something useful: how much time do people spend in the park?
#
# > We'll analyse a couple of Strava activities and determine how long this person spends enjoying the view over the river on their runs. __Note:__ Serverless doesn't yet allow access to Workspace files, so copying to Volumes.

# %%
# %python
# update to your preferred location
# - you have to pre-generate the volumes path
data_path = "/Volumes/geospatial_docs/strava/data"
os.environ["DATA_PATH"] = data_path

# %%
# %sh 
cp -n ./strava/*.csv $DATA_PATH
ls -lh $DATA_PATH
# Out:
# cp: warning: behavior of -n is non-portable and may change in future; use --update=none instead
# cp: cannot stat './strava/*.csv': No such file or directory
# total 2.6M
# -rwxrwxrwx 1 nobody nogroup 149K Feb 11 00:38 2023-10-17.csv
# -rwxrwxrwx 1 nobody nogroup 1.2M Feb 11 00:38 2023-11-04.csv
# -rwxrwxrwx 1 nobody nogroup 669K Feb 11 00:38 2024-07-25.csv
# -rwxrwxrwx 1 nobody nogroup 629K Feb 11 00:38 2024-10-06.csv

# %%
# %python
(
  spark.read
  .csv(data_path, header=True, inferSchema=True)
  .withColumnRenamed("track_se_1", "track_seg_point_id")
  .select(
    DBF.st_geomfromtext("wkt", F.lit(4326)).alias("geom_4326"),
    "WKT", "track_seg_point_id", "ele", "time"
  )
  .where("!st_isempty(WKT)")
  .withColumn("user", F.lit("uuʎ˥ ʇɹɐnʇS"))
  .withColumn("time", F.to_timestamp("time", "yyyy/MM/dd HH:mm:ss.SSS"))
  .withColumn("date", F.date_trunc("day", "time"))
  .withColumn("h3", DBF.h3_pointash3("WKT", 9))
  ).createOrReplaceTempView("run_track")

print(f"count? {spark.table('run_track').count():,}")
spark.table("run_track").drop("geom_4326").limit(3).display()
# Out:
# count? 30,155
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>WKT</th><th>track_seg_point_id</th><th>ele</th><th>time</th><th>user</th><th>date</th><th>h3</th></tr></thead><tbody><tr><td>POINT (-0.041528 51.413022)</td><td>274</td><td>-19.0</td><td>2023-11-04T07:37:08Z</td><td>uuʎ˥ ʇɹɐnʇS</td><td>2023-11-04T00:00:00Z</td><td>617438094914486271</td></tr><tr><td>POINT (-0.041535 51.413051)</td><td>275</td><td>-19.0</td><td>2023-11-04T07:37:09Z</td><td>uuʎ˥ ʇɹɐnʇS</td><td>2023-11-04T00:00:00Z</td><td>617438094914486271</td></tr><tr><td>POINT (-0.041531 51.41308)</td><td>276</td><td>-19.0</td><td>2023-11-04T07:37:10Z</td><td>uuʎ˥ ʇɹɐnʇS</td><td>2023-11-04T00:00:00Z</td><td>617438094914486271</td></tr></tbody></table></div>

# %%
# %python
displayHTML("""<img src="data:image/jpg;base64,..." width="25%">""")
# Out:
# <img src="data:image/jpg;base64,..." width="25%">

# %%
# %python
## -- uncomment to run in databricks
# run_track_pdf = spark.table("run_track").drop("geom_4326").sample(fraction=0.5).toPandas()
# gs = gpd.GeoSeries.from_wkt(run_track_pdf["WKT"], crs=4326)
# run_track_pdf["geometry"] = gs
# gdf = gpd.GeoDataFrame(run_track_pdf, geometry="geometry")
# gdf.explore(column="date")

# %%
# %python
displayHTML("""<img src="data:image/jpg;base64,..." width="25%">""")
# Out:
# <img src="data:image/jpg;base64,..." width="25%">

# %%
# %python
## -- uncomment to run in databricks
# run_track_pdf = (
#   spark.table("run_track")
#   .withColumn("h3_geom", DBF.h3_boundaryaswkt("h3"))
#   .select("h3", "h3_geom", "date")
#   .distinct()
#   ).toPandas()
# gs = gpd.GeoSeries.from_wkt(run_track_pdf["h3_geom"], crs=4326)
# run_track_pdf["geometry"] = gs
# gdf = gpd.GeoDataFrame(run_track_pdf, geometry="geometry")
# gdf.explore(column="date")

# %%
# %python
events_in_aoi_df = (
  spark.table("run_track").alias("t")
  .join(
    other=spark.table("indexed_areas").alias("a"),
    on=F.col("t.h3")==F.col("a.cellid"),
    how="inner"
    )
  .where(
    F.col("a.core") | 
    DBF
      .st_intersects(
        DBF.st_geomfromwkb("a.chip", F.lit(4326)), 
        "t.geom_4326"
      )
  )
  .select("user", "date", "time", "track_seg_point_id", "ele", "WKT")
)
print(f"count? {events_in_aoi_df.count():,}")
events_in_aoi_df.limit(3).display()
# Out:
# count? 1,322
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user</th><th>date</th><th>time</th><th>track_seg_point_id</th><th>ele</th><th>WKT</th></tr></thead><tbody><tr><td>uuʎ˥ ʇɹɐnʇS</td><td>2023-11-04T00:00:00Z</td><td>2023-11-04T08:24:34Z</td><td>3120</td><td>11.0</td><td>POINT (0.000273 51.472257)</td></tr><tr><td>uuʎ˥ ʇɹɐnʇS</td><td>2023-11-04T00:00:00Z</td><td>2023-11-04T08:24:35Z</td><td>3121</td><td>11.0</td><td>POINT (0.000263 51.472282)</td></tr><tr><td>uuʎ˥ ʇɹɐnʇS</td><td>2023-11-04T00:00:00Z</td><td>2023-11-04T08:24:36Z</td><td>3122</td><td>11.0</td><td>POINT (0.000255 51.472309)</td></tr></tbody></table></div>

# %%
# %python
displayHTML("""<img src="data:image/jpg;base64,..." width="25%">""")
# Out:
# <img src="data:image/jpg;base64,..." width="25%">

# %%
# %python
## -- uncomment to run in databricks
# events_pdf = events_in_aoi_df.toPandas()
# gs = gpd.GeoSeries.from_wkt(events_pdf["WKT"], crs=4326)
# events_pdf["geometry"] = gs
# gdf = gpd.GeoDataFrame(events_pdf, geometry="geometry")
# gdf.explore(column="date")

# %%
# %python
(
    events_in_aoi_df.groupBy("user", "date")
    .agg(F.min("time").alias("in_time"), F.max("time").alias("out_time"))
    .withColumn(
        "dwell",
        #F.timestamp_diff(start=F.col("in_time"), end=F.col("out_time"), unit="SECOND") # <- Spark 4.0+
        F.col("out_time").cast("long") - F.col("in_time").cast("long")                  # <- Spark 3.x
    )
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user</th><th>date</th><th>in_time</th><th>out_time</th><th>dwell</th></tr></thead><tbody><tr><td>uuʎ˥ ʇɹɐnʇS</td><td>2023-11-04T00:00:00Z</td><td>2023-11-04T08:24:34Z</td><td>2023-11-04T08:40:29Z</td><td>955</td></tr><tr><td>uuʎ˥ ʇɹɐnʇS</td><td>2024-07-25T00:00:00Z</td><td>2024-07-25T18:35:59Z</td><td>2024-07-25T18:49:28Z</td><td>809</td></tr><tr><td>uuʎ˥ ʇɹɐnʇS</td><td>2024-10-06T00:00:00Z</td><td>2024-10-06T08:45:03Z</td><td>2024-10-06T08:57:44Z</td><td>761</td></tr><tr><td>uuʎ˥ ʇɹɐnʇS</td><td>2023-10-17T00:00:00Z</td><td>2023-10-17T06:48:45Z</td><td>2023-10-17T06:56:37Z</td><td>472</td></tr></tbody></table></div>
